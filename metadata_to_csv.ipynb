# %%
import json
import pandas as pd

# %%
games_file = open('metadata/games.json')
games_json = json.load(games_file)
data=[]

for game in games_json['games']:
    data.append(game)

games_df=pd.DataFrame(data)
  
games_file.close()

teams_file = open('metadata/teams.json')
teams_json = json.load(teams_file)
data=[]
for game in teams_json['teams']:
    data.append(game)

teams_df=pd.DataFrame(data)
  
teams_file.close()

# %%
games_df= games_df.merge(teams_df, left_on='homeTeamId', right_on='id', how='left')
games_df.drop(columns=['id_y','abbrev','nbaId_y'],inplace=True)
games_df.rename(columns={'id_x':'id','nbaId_x':'nbaId',"name": "homeTeamName"}, inplace=True)
games_df.head()
# Out:
#                                      id                            homeTeamId  \
# 0  befdf1c0-e9b8-489a-80ff-687345af6359  feb4cfab-89ef-11e6-8b77-a45e60e298d3
# 1  e981ee52-d3dc-4c65-a82f-ad87f4b28ff9  feb4d380-89ef-11e6-9eb6-a45e60e298d3
# 2  e0999c2e-8ef3-4e35-8ac8-323cec0d8604  feb4cfab-89ef-11e6-8b77-a45e60e298d3
# 3  f5d39eef-b330-4502-8c22-55fe3bc94ccc  feb4d380-89ef-11e6-9eb6-a45e60e298d3
# 4  ca16e5da-dd8e-4a13-9876-f40740d74dd2  feb4d380-89ef-11e6-9eb6-a45e60e298d3
#
#                              awayTeamId       nbaId     type  \
# 0  feb4d380-89ef-11e6-9eb6-a45e60e298d3  0042200407  playoff
# 1  feb4cfab-89ef-11e6-8b77-a45e60e298d3  0042200406  playoff
# 2  feb4d380-89ef-11e6-9eb6-a45e60e298d3  0042200405  playoff
# 3  feb4cfab-89ef-11e6-8b77-a45e60e298d3  0042200404  playoff
# 4  feb4cfab-89ef-11e6-8b77-a45e60e298d3  0042200403  playoff
#
#                   path      prefix                   lastMod  completed  \
# 0  2022-23/0042200407/  0042200407                      None      False
# 1  2022-23/0042200406/  0042200406                      None      False
# 2  2022-23/0042200405/  0042200405  2023-06-13T14:44:38.000Z       True
# 3  2022-23/0042200404/  0042200404  2023-06-13T17:26:53.000Z       True
# 4  2022-23/0042200403/  0042200403  2023-06-08T17:08:53.000Z       True
#
#   trackingState  season  year  month  day    homeTeamName
# 0          None    2022  2023      6   18  Denver Nuggets
# 1          None    2022  2023      6   15      Miami Heat
# 2          full    2022  2023      6   12  Denver Nuggets
# 3          full    2022  2023      6    9      Miami Heat
# 4          full    2022  2023      6    7      Miami Heat

# %%
games_df= games_df.merge(teams_df, left_on='awayTeamId', right_on='id', how='left')
games_df.drop(columns=['id_y','abbrev','nbaId_y'],inplace=True)
games_df.rename(columns={'id_x':'id','nbaId_x':'nbaId',"name": "awayTeamName"}, inplace=True)
games_df.head()
# Out:
#                                      id                            homeTeamId  \
# 0  befdf1c0-e9b8-489a-80ff-687345af6359  feb4cfab-89ef-11e6-8b77-a45e60e298d3
# 1  e981ee52-d3dc-4c65-a82f-ad87f4b28ff9  feb4d380-89ef-11e6-9eb6-a45e60e298d3
# 2  e0999c2e-8ef3-4e35-8ac8-323cec0d8604  feb4cfab-89ef-11e6-8b77-a45e60e298d3
# 3  f5d39eef-b330-4502-8c22-55fe3bc94ccc  feb4d380-89ef-11e6-9eb6-a45e60e298d3
# 4  ca16e5da-dd8e-4a13-9876-f40740d74dd2  feb4d380-89ef-11e6-9eb6-a45e60e298d3
#
#                              awayTeamId       nbaId     type  \
# 0  feb4d380-89ef-11e6-9eb6-a45e60e298d3  0042200407  playoff
# 1  feb4cfab-89ef-11e6-8b77-a45e60e298d3  0042200406  playoff
# 2  feb4d380-89ef-11e6-9eb6-a45e60e298d3  0042200405  playoff
# 3  feb4cfab-89ef-11e6-8b77-a45e60e298d3  0042200404  playoff
# 4  feb4cfab-89ef-11e6-8b77-a45e60e298d3  0042200403  playoff
#
#                   path      prefix                   lastMod  completed  \
# 0  2022-23/0042200407/  0042200407                      None      False
# 1  2022-23/0042200406/  0042200406                      None      False
# 2  2022-23/0042200405/  0042200405  2023-06-13T14:44:38.000Z       True
# 3  2022-23/0042200404/  0042200404  2023-06-13T17:26:53.000Z       True
# 4  2022-23/0042200403/  0042200403  2023-06-08T17:08:53.000Z       True
#
#   trackingState  season  year  month  day    homeTeamName    awayTeamName
# 0          None    2022  2023      6   18  Denver Nuggets      Miami Heat
# 1          None    2022  2023      6   15      Miami Heat  Denver Nuggets
# 2          full    2022  2023      6   12  Denver Nuggets      Miami Heat
# 3          full    2022  2023      6    9      Miami Heat  Denver Nuggets
# 4          full    2022  2023      6    7      Miami Heat  Denver Nuggets

# %%
games_df.to_csv('games_with_team_names.csv')
